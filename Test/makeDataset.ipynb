# %%
# 이 코랩 파일은 챗봇 학습을 위한 데이터셋 구성 단계에서 작성된 파일입니다.

# 허깅페이스에 오픈된 한국어 데이터셋(불특정)을 받아와서 안의 내용만 삭제하고, 형태를 유지하면서 새로운 내용들로 작성합니다.
# 새로 작성된 데이터셋을 허깅페이스 저장소에 업로드합니다.

# %% [markdown]
# # 데이터셋 수정 및 업로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ...

# %%
# #@title 🤗 Choose Dataset
# dataset = 'kyujinpy/Open-platypus-Commercial' #@param {type: "string"}

# %%
# #@title 🤗 Choose Dataset
# dataset = 'beomi/KoAlpaca-v1.1a' #@param {type: "string"}

# %%
dataset = 'taeseo06/Taeseo06-personalization-dataset' #@param {type: "string"}

# %%
dataset2 = 'llm-wizard/alpaca-gpt4-data-zh' #@param {type: "string"}

# %%
###########################################
# 5-1. 데이터셋 다운로드
# dataset 링크를 바꾸면 됨.
data = load_dataset(dataset)
print(data['train']) # 개수
# Out:
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 720
# })

# %%
data['train']['instruction']

# %%
data2 = load_dataset(dataset2)
print(data2['train']) # 개수
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/48818 [00:00<?, ? examples/s]
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 48818
# })

# %%
print(data) # 데이터셋 구조 파악
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 720
#     })
# })

# %%
print(data2) # 데이터셋 구조 파악
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 48818
#     })
# })

# %%
# # import pickle

# # with open("/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_1.pickle", "wb")  as  fw:
# #       pickle.dump(data, fw)


# data.save_to_disk('/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_1')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/19079 [00:00<?, ? examples/s]

# %%
# import pickle

# with open("/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_2/dataset.pickle", "wb")  as  fw:
#       pickle.dump(data, fw)

# %%
# with open("/content/drive/My Drive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset.pickle", "wb") as fw:
#     pickle.dump(data, fw)

# %%
# data = load_dataset(dataset)
new_dataset = data['train'][:2] # 새로운 데이터셋 생성 - 2개 인풋만 남김
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?', '선린인터넷고등학교의 위치를 알려줘'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.', '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다']}

# %%
new_dataset2 = data2['train'][:2] # 새로운 데이터셋 생성 - 2개 인풋만 남김
new_dataset2
# Out:
# {'instruction': ['保持健康的三个提示。', '三原色是什么？'],
#  'input': ['', ''],
#  'output': ['以下是保持健康的三个提示：\n\n1. 保持身体活动。每天做适当的身体运动，如散步、跑步或游泳，能促进心血管健康，增强肌肉力量，并有助于减少体重。\n\n2. 均衡饮食。每天食用新鲜的蔬菜、水果、全谷物和脂肪含量低的蛋白质食物，避免高糖、高脂肪和加工食品，以保持健康的饮食习惯。\n\n3. 睡眠充足。睡眠对人体健康至关重要，成年人每天应保证 7-8 小时的睡眠。良好的睡眠有助于减轻压力，促进身体恢复，并提高注意力和记忆力。',
#   '三原色通常指的是红色、绿色和蓝色（RGB）。它们是通过加色混合原理创建色彩的三种基础颜色。在以发光为基础的显示设备中（如电视、计算机显示器、智能手机和平板电脑显示屏）, 三原色可混合产生大量色彩。其中红色和绿色可以混合生成黄色，红色和蓝色可以混合生成品红色，蓝色和绿色可以混合生成青色。当红色、绿色和蓝色按相等比例混合时，可以产生白色或灰色。\n\n此外，在印刷和绘画中，三原色指的是以颜料为基础的红、黄和蓝颜色（RYB）。这三种颜色用以通过减色混合原理来创建色彩。不过，三原色的具体定义并不唯一，不同的颜色系统可能会采用不同的三原色。']}

# %%
del new_dataset2['input'] # 기존 데이터셋에서 필요없는 요소가 있으면 제거

# %%
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?', '선린인터넷고등학교의 위치를 알려줘'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.', '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다']}

# %% [markdown]
# ---
# # 테스트

# %%
new_dataset = {}

# %%
dataset_test = [
    "선린인터넷고등학교는 어느 동네에 위치해있어?", "선린인터넷고등학교는 용산구 남영동에 위치해있습니다.",
    "선린인터넷고등학교의 위치를 알려줘", "선린인터넷고등학교는 용산구 원효로 97길에 위치해있습니다.",
    "학교의 동네를 알려줘", "선린인터넷고등학교는 서울시 용산구 남영동에 위치해있습니다.",
    "선린인터넷고등학교의 자세한 위치를 알려줘", "선린인터넷고등학교는 서울특별시 용산구 원효로 97길 33-4에 위치해있습니다.",
    "선린인터넷고등학교의 자세한 위치를 알고싶어", "선린인터넷고등학교의 자세한 주소는 서울특별시 용산구 원효로 97길 33-4 입니다.",
    "남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?", "남영역에서 선린인터넷고등학교 까지 도보로 약 7분 입니다.\n남영역 출구 바로 건너편에 선린인터넷고등학교가 자리하고있으며, 횡단보도를 2번 건너면 선린인터넷고등학교 정문이 나옵니다.",
    "선린인터넷고등학교 주변에는 뭐가있어?", "선린인터넷고등학교 주변에는 숙명여자대학교, 선린중학교, 남영역 등이 있습니다.",
    "선린인터넷고등학교 주변에 숙명여자대학교가 있어?", "네, 선린인터넷고등학교 주변에는 숙명여자대학교가 있습니다.\n정획하게는, 선린 중학교 후문 건너편 지하주차장을 건너면 숙명여자대학교 캠퍼스가 나옵니다. 도보로 약 7분 정도가 소요됩니다.",
    "선린인터넷고등학교 후문은 어떻게 갈 수 있어?", "선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다.\n후문은 4호관과 맞닿아있는 선린중학교 운동장을 돌아서 접근할 수 있으며, 4호관에서 후문까지 약 5분가량 소요됩니다.",
    "선린인터넷고등학교 후문에서 정문까지는 거리가 멀어?", "선린인터넷고등학교 정문과 후문 사이를 이동하는데 소요되는 시간은 약 10분이며, 4호관에서 후문까지는 약 5분가량 소요됩니다.\n선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다.",
    "선린인터넷고등학교는 남영역과 효창공원역 중에서 어떤 역과 더 가까워?", "선린인터넷고등학교 정문에서는 남영역과 더 가깝습니다. 선린인터넷고등학교에서 남영역까지는 약 7분가량 소요됩니다.\n효창공원역에서 선린인터넷고등학교 까지는 약 15분이 소요됩니다. 그러나 효창공원역 앞에서 버스를 이용하면 소요되는 시간은 더 줄어들 수도 있습니다.",
    "효창공원역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?", "효창공원역에서 선린인터넷고등학교 까지 도보로 약 15분이 소요됩니다.\n효창공원역 출구로 나와서 금양초등학교 방면으로 걷다보면 선린중학교가 먼저 나오고, 선린중학교를 거쳐서 선린인터넷고등학교로 들어올 수 있습니다. 그러나 효창공원역 출구에서 0411 혹은 400번 버스를 이용하면 소요되는 시간은 더 줄어들 수도 있습니다.",
    "효창공원역에서 선린인터넷고등학교 까지 버스를 이용하고 싶어", "효창공원역 출구에서 0411 혹은 400번 버스를 이용하여 숙명여대 정류장에 내려서, 숙명여대 지하주차장을 통과하면 선린중학교가 나옵니다.\n선린중학교를 거쳐서 선린인터넷고등학교로 들어올 수 있습니다.",


    "선린인터넷고등학교는 선린중학교랑 같이 있어?", "네, 선린인터넷고등학교는 선린중학교와 이어져 있습니다.\n등/하교 시간에 고등학교 학생들이 선린중학교 정문을 이용하거나, 선린중학교 학생들이 선린인터넷고등학교 정문을 이용하기도 합니다.",
    "선린인터넷고등학교 후문은 어디에 있어?", "선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용되고 있습니다.\n선린인터넷고등학교 학생들이 등/하교 시간에 선린중학교를 이용할 수 있습니다. 또한, 선린인터넷고등학교 정문도 선린중학교 학생들이 등/하교 시간에 이용할 수 있습니다.",
    "후문은 어디에 있어?", "후문은 선린중학교 정문과 함께 사용되고 있습니다.\n후문은 4호관과 맞닿아 있는 선린중학교 운동장을 돌아서 갈 수 있으며, 4호관에서 후문까지는 약 5분가량 소요됩니다.",

    "후문은 어떻게 갈 수 있어?", "후문은 선린중학교 정문과 함께 사용되고 있습니다.\n후문은 4호관과 맞닿아있는 선린중학교 운동장을 돌아서 갈 수 있으며, 4호관에서 후문 까지는 약 5분가량 소요됩니다.",
    "정문에서 후문으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 따라 쭉 올라가면 후문이 나옵니다.",
    "1호관에서 후문으로 가는 길을 알려줘", "1호관 2층 학생회실 옆 외부 출입문로 나가 선린중학교 운동장을 따라 돌면 후문으로 이동할 수 있습니다.",
    "2호관에서 후문으로 가는 길을 알려줘", "2호관 밖으로 나가 선린중학교 운동장을 따라 돌면 후문으로 이동할 수 있습니다.",
    "3호관에서 후문으로 가는 길을 알려줘", "3호관 밖으로 나가 선린중학교 운동장을 따라 돌면 후문으로 이동할 수 있습니다.",
    "4호관에서 후문으로 가는 길을 알려줘", "4호관 밖으로 나가 선린중학교 운동장을 따라 돌면 후문으로 이동할 수 있습니다.",

    "4호관은 어디에 있어?", "4호관은 2호관 맞은편에 위치해 있으며, 3호관과 2층에서 통로로 연결되어 있습니다.",
    "4호관은 어떻게 갈 수 있어?", "4호관은 2호관 맞은편에 위치해 있으며, 3호관과 2층에서 통로로 연결되어 있습니다.\n따라서 영상교육관 쪽 외부 출입문으로 들어가거나, 3호관 2층에 연결되어 있는 통로를 통해서 이동할 수 있습니다.",
    "4호관으로 가는 길을 알려줘", "4호관은 2호관 맞은편에 위치해 있으며, 3호관과 2층에서 통로로 연결되어 있습니다.\n따라서 영상교육관 쪽 외부 출입문으로 들어가거나, 3호관 2층에 연결되어 있는 통로를 통해서 이동할수 있습니다.",
    "정문에서 4호관으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 통해서 4호관 건물로 올라올 수 있습니다.\n다른 방법으로는 1호관, 2호관, 3호관을 차례로 거쳐서 3호관 2층에 연결되어 있는 통로를 통해서 4호관으로 이동할 수도 있습니다.",
    "1호관에서 4호관으로 가는 길을 알려줘", "1호관 3층에 2호관과 연결되어 있는 통로를 통해서 2호관, 3호관을 차례로 거쳐서 4호관으로 이동할 수 있습니다.",
    "2호관에서 4호관으로 가는 길을 알려줘", "3호관을 거쳐서 3호관 2층에 연결되어 있는 통로를 통하면 4호관으로 이동할 수 있습니다.",
    "3호관에서 4호관으로 가는 길을 알려줘", "3호관 2층에 4호관으로 연결되는 통로를 이용하면 4호관으로 이동할 수 있습니다.",
    "후문에서 4호관으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면 4호관이 바로 나옵니다.",

    "3호관은 어디에 있어?", "3호관은 매점 맞은편에 위치해 있으며\n2호관, 4호관과 연결되어 있습니다.",
    "3호관은 어떻게 갈 수 있어?", "3호관은 매점 맞은편에 위치해 있으며\n2호관, 4호관과 연결되어 있습니다.\n따라서 매점 맞은편에 위치한 급식실 쪽 외부 출입문으로 들어가거나, 2호관 또는 4호관에 연결된 통로를 통해서 이동할 수 있습니다.",
    "3호관으로 가는 길을 알려줘", "3호관은 매점 맞은편에 위치해 있으며\n2호관, 4호관과 연결되어 있습니다.\n따라서 매점 맞은편에 위치한 급식실 쪽 외부 출입문으로 들어가거나, 2호관 또는 4호관에 연결된 통로를 통해서 이동할 수 있습니다.",
    "정문에서 3호관으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 통해서 3호관 건물로 올라갈 수 있습니다.\n다른 방법으로는 1호관, 2호관을 거쳐서 3호관으로 이동할 수도 있습니다.",
    "1호관에서 3호관으로 가는 길을 알려줘", "1호관 3층에 2호관과 연결되어 있는 통로를 통해서 2호관으로 이동하고, 2호관을 거쳐서 3호관으로 이동할 수 있습니다.",
    "2호관에서 3호관으로 가는 길을 알려줘", "2호관은 3호관과 직접적으로 연결되어 있기 때문에, 3호관으로 곧바로 이동할 수 있습니다.",
    "4호관에서 3호관으로 가는 길을 알려줘", "4호관은 3호관과 직접적으로 연결되어 있기 때문에, 4호관 2층 연결통로를 통해서 곧바로 3호관으로 이동할 수 있습니다.",
    "후문에서 3호관으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌아서, 매점 맞은편에 있는 급식실 쪽 외부 출입문으로 3호관에 들어갈 수 있습니다.",

    "2호관은 어디에 있어?", "2호관은 4호관 맞은편에 위치해 있으며\n1호관, 3호관과 연결되어 있습니다.",
    "2호관은 어떻게 갈 수 있어?", "2호관은 4호관 맞은편에 위치해 있으며\n1호관, 3호관과 연결되어 있습니다.\n따라서 4호관 맞은편에 위치한 외부 출입문으로 들어가거나, 1호관 3층 또는 3호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "2호관으로 가는 길을 알려줘", "2호관은 4호관 맞은편에 위치해 있으며\n1호관, 3호관과 연결되어 있습니다.\n따라서 4호관 맞은편에 위치한 외부 출입문으로 들어가거나, 1호관 3층 또는 3호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "정문에서 2호관으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 통해서 2호관 건물로 올라갈 수 있습니다.\n다른 방법으로는 1호관 2층 학생회실 옆 출입문으로 나가 2호관으로 이동하거나, 1호관 3층에 2호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "1호관에서 2호관으로 가는 길을 알려줘", "1호관 2층 학생회실 옆 출입문로 나가 2호관으로 이동하거나, 1호관 3층에 2호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "3호관에서 2호관으로 가는 길을 알려줘", "3호관은 2호관과 직접적으로 연결되어 있기 때문에, 2호관으로 곧바로 이동할 수 있습니다.",
    "4호관에서 2호관으로 가는 길을 알려줘", "4호관 2층에 3호관과 연결되어 있는 통로를 통해서 3호관을 거쳐서 2호관으로 이동할 수 있습니다.",
    "후문에서 2호관으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면, 이동하는 방향 그대로 2호관으로 들어갈 수 있습니다.",

    "1호관은 어디에 있어?", "1호관은 운동장과 맞닿아 있으며, 정문에서 교내로 올라오는 길 오른쪽에 위치해 있습니다.",
    "1호관은 어떻게 갈 수 있어?", "1호관은 운동장 맞은편에 위치해 있으며, 2호관과 연결되어 있습니다.\n따라서 운동장 오른쪽에 위치한 외부 출입문으로 들어가거나, 2호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "1호관으로 가는 길을 알려줘", "1호관은 운동장 맞은편에 위치해 있으며, 2호관과 연결되어 있습니다.\n따라서 운동장 오른쪽에 위치한 외부 출입문으로 들어가거나, 2호관과 연결된 통로를 통해서 이동할 수 있습니다.",
    "정문에서 1호관으로 가는 길을 알려줘", "정문에서 교내로 올라오는 길 오른쪽에 위치한 외부 출입문을 이용하면 1호관으로 들어갈 수 있습니다.",
    "2호관에서 1호관으로 가는 길을 알려줘", "2호관 2층에 1호관과 연결되어 있는 통로를 통해서 1호관으로 이동할 수 있습니다.",
    "3호관에서 1호관으로 가는 길을 알려줘", "3호관은 2호관과 연결되어 있기 때문에, 2호관으로 이동 후 2층에 1호관과 연결되어 있는 통로를 통해서 1호관으로 이동할 수 있습니다.",
    "4호관에서 1호관으로 가는 길을 알려줘", "4호관 2층에 3호관과 연결되어 있는 통로를 통해서 3호관, 2호관을 차례로 거쳐서 1호관으로 이동할 수 있습니다.",
    "후문에서 1호관으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면, 이동하는 방향 그대로 2호관 옆에 위치한 1호관 출입문을 이용하면 1호관으로 들어갈 수 있습니다.",


    "매점은 어디에 있어?", "매점은 4호관과 3호관 사이에 위치해 있으며, 영상교육관 건물 옆에 있습니다.",
    "매점은 어떻게 갈 수 있어?", "매점은 4호관과 3호관 사이에 위치해 있으며, 영상교육관 건물 옆에 있습니다.\n따라서 3호관 외부 출입문 맞은편에 위치한 매점 출입문으로 들어갈 수 있습니다.",
    "매점으로 가는 길을 알려줘", "매점은 4호관과 3호관 사이에 위치해 있으며, 영상교육관 건물 옆에 있습니다.\n따라서 3호관 외부 출입문 맞은편에 위치한 매점 출입문으로 들어갈 수 있습니다.",
    "정문에서 매점으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 통해서 영상교육관 건물 옆 매점으로 이동할 수 있습니다.",
    "1호관에서 매점으로 가는 길을 알려줘", "1호관 2층 학생회실 옆 출입문으로 나가면 영상교육관 건물 옆 매점으로 이동할 수 있습니다.",
    "2호관에서 매점으로 가는 길을 알려줘", "2호관 밖으로 나가 영상교육관 건물 옆 매점으로 이동하거나, 3호관과 연결되어 있는 통로를 통해 3호관으로 이동하고 1층 급식실 옆 출입문으로 나가면 매점으로 이동할 수 있습니다.",
    "3호관에서 매점으로 가는 길을 알려줘", "매점은 4호관과 3호관 사이에 위치해 있습니다. 따라서, 3호관 1층 출입문을 통해 나가면 바로 앞 매점을 이용할 수 있습니다.",
    "4호관에서 매점으로 가는 길을 알려줘", "매점은 4호관과 3호관 사이에 위치해 있습니다. 따라서, 4호관 1층 출입문을 통해 나가면 바로 앞 매점을 이용할 수 있습니다.",
    "후문에서 매점으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면, 영상교육관 건물 옆에 위치한 매점을 이용할 수 있습니다.",
    "매점에서 판매하는 상품들의 종류를 알고싶어", "매점은 다양한 식품들을 취급합니다.\n매점의 특성상 매일 판매하는 상품들이 바뀌기도 하며, 재고에 따라 판매하지 않는 제품이 있을 수도 있습니다.\n따라서 매점에서 운영하는 소통 창구인 매점 인스타그램을 참조하는게 도움이 될 수도 있습니다. 매점에서 운영하는 인스타그램 아이디는 sunrin_oasis입니다.",

    "체육관은 어디에 있어?", "체육관은 정문과 운동장 사이에 있습니다.",
    "체육관은 어떻게 갈 수 있어?", "체육관은 정문과 운동장 사이에 있습니다.\n따라서 정문 왼쪽에 위치한 1층 외부 출입문을 통해서 이동하거나, 운동장과 맞닿아 있는 2층 외부 출입문을 통해서 체육관으로 이동할 수 있습니다.",
    "체육관으로 가는 길을 알려줘", "체육관은 정문과 운동장 사이에 있습니다.\n따라서 정문 왼쪽에 위치한 1층 외부 출입문을 통해서 이동하거나, 운동장과 맞닿아 있는 2층 외부 출입문을 통해서 체육관으로 이동할 수 있습니다",
    "정문에서 체육관으로 가는 길을 알려줘", "정문 왼쪽에 위치한 1층 외부 출입문을 통해서 체육관으로 이동할 수 있습니다.",
    "1호관에서 체육관으로 가는 길을 알려줘", "1호관 밖으로 나가 운동장과 맞닿아 있는 2층 외부 출입문으로 이동할 수 있습니다.",

    "영상교육관은 어디에 있어?", "영상교육관은 2호관, 3호관, 4호관과 맞닿아 있습니다.",
    "영상교육관은 어떻게 갈 수 있어?", "영상교육관은 2호관, 3호관, 4호관과 맞닿아 있습니다.\n따라서 각 호관 외부로 나와 영상교육관으로 이동할 수 있습니다.",
    "영상교육관으로 가는 길을 알려줘", "영상교육관은 2호관, 3호관, 4호관과 맞닿아 있습니다.\n따라서 각 호관 외부로 나와 영상교육관으로 이동할 수 있습니다.",
    "정문에서 영상교육관으로 가는 길을 알려줘", "정문 왼쪽에 위치한 세계로미래로 산책로를 통해서 영상교육관 건물로 올라올 수 있습니다.\n다른 방법으로는 1호관으로 이동 후 1호관 2층 학생회실 옆 외부 출입문으로 나가서 영상교육관으로 이동할 수도 있습니다.",
    "1호관에서 영상교육관으로 가는 길을 알려줘", "1호관 2층 학생회실 옆 외부 출입문으로 나가서 영상교육관으로 이동할 수 있습니다.",
    "2호관에서 영상교육관으로 가는 길을 알려줘", "2호관 밖으로 나가서 영상교육관으로 이동할 수 있습니다.",
    "3호관에서 영상교육관으로 가는 길을 알려줘", "3호관 밖으로 나가서 영상교육관으로 이동할 수 있습니다.",
    "4호관에서 영상교육관으로 가는 길을 알려줘", "4호관 밖으로 나가서 영상교육관으로 이동할 수 있습니다.",
    "후문에서 영상교육관으로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면, 영상교육관으로 이동할 수 있습니다.",

    "학생회실은은 어디에 있어?", "학생회실은 1호관 2층 왼쪽 끝에 위치해 있습니다.",
    "학생회실은 어떻게 갈 수 있어?", "학생회실은 1호관 2층 왼쪽 끝에 위치해 있습니다.",
    "학생회실으로 가는 길을 알려줘", "학생회실은 1호관 2층 왼쪽 끝에 위치해 있습니다.",
    "학생회실 위치를 알려줘", "학생회실은 1호관 2층 왼쪽 끝에 위치해 있습니다.",
    "정문에서 학생회실로 가는 길을 알려줘", "정문에서 교내로 올라오는 길 오른쪽에 위치한 외부 출입문을 이용하면 1호관으로 들어갈 수 있습니다.\n1호관에 들어온 후 2층 왼쪽 끝에 위치한 학생회실로 이동하면 됩니다.",
    "1호관에서 학생회실로 가는 길을 알려줘", "1호관 2층 왼쪽 끝에 위치한 학생회실로 이동하면 됩니다.",
    "2호관에서 학생회실로 가는 길을 알려줘", "2호관 3층에 1호관과 위치한 통로를 통해서 1호관으로 이동하거나, 2호관 밖으로 나와서 1호관으로 이동할 수 있습니다.",
    "3호관에서 학생회실로 가는 길을 알려줘", "3호관과 2호관은 연결되어 있기 때문에 2호관을 거쳐 1호관으로 이동하거나, 3호관 밖으로 나와서 1호관으로 이동할 수 있습니다.",
    "4호관에서 학생회실로 가는 길을 알려줘", "4호관 2층에 3호관과 연결된 통로를 통해 3호관, 2호관을 차례로 거쳐서 1호관으로 이동하거나, 4호관 밖으로 나와서 1호관으로 이동할 수 있습니다.",
    "후문에서 학생회실로 가는 길을 알려줘", "후문에서 선린중학교 운동장을 따라 돌면, 이동하는 방향 그대로 2호관 옆에 위치한 1호관 출입문을 이용하면 바로 학생회실로 갈 수 있습니다.",

    "급식실은 어디에 있어?", "급식실은 3호관 1층 중앙에 위치해 있습니다.",
    "급식실은 어떻게 갈 수 있어?", "급식실은 3호관 1층 중앙에 위치해 있습니다.\n따라서 매점 맞은편에 있는 매점 외부 출입문으로 들어가거나, 3호관 1층 계단과 연결되어 있는 출입문을 통해 급식실로 이동할 수 있습니다.",
    "급식실로 가는 길을 알려줘", "급식실은 3호관 1층 중앙에 위치해 있습니다.\n따라서 매점 맞은편에 있는 매점 외부 출입문으로 들어가거나, 3호관 1층 계단과 연결되어 있는 출입문을 통해 급식실로 이동할 수 있습니다.",
    "1호관에서 급식실로 가는 길을 알려줘", "1호관 2층 학생회실 옆 외부출입문으로 나가서 급식실로 이동할 수 있습니다.",
    "2호관에서 급식실로 가는 길을 알려줘", "2호관 밖으로 나가서 급식실로 이동할 수 있습니다.",
    "3호관에서 급식실로 가는 길을 알려줘", "3호관 1층으로 내려가서 계단과 연결되어 있는 출입문으로 통해 급식실로 이동할 수 있습니다.",

    "급식 시간을 알려줘", "선린인터넷고등학교 급식 시간은 12시30분 부터 1시30분 까지 1시간 입니다.",
    "학년별 급식 순서를 알려줘", "12시30분 부터 급식시간이 시작되며, 3학년, 2학년, 1학년 순서대로 급식실에 들어갈 수 있습니다.",
    "급식 순서를 알려줘", "12시30분 부터 급식시간이 시작되며, 3학년, 2학년, 1학년 순서대로 급식실에 들어갈 수 있습니다.",
    "급식 메뉴를 알려줘", "매일 급식 메뉴는 학교 홈페이지 혹은 학생회 공식 인스타그램 스토리에서 확인할 수 있으며, 나이스(교육청)의 점심메뉴 api를 활용하는 시중의 여러 서비스에서도 확인할 수 있습니다.\n매월 식단은 월 초에 공식적인 가정통신문으로 학생들에게 안내합나다. 다만, 급식 식단은 식자재 수급현황, 학교일정 등으로 사전공지 없이 변경될 수 있으므로 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
    "오늘 급식을 알려줘", "매일 급식 메뉴는 학교 홈페이지 혹은 학생회 공식 인스타그램 스토리에서 확인할 수 있으며, 나이스(교육청)의 점심메뉴 api를 활용하는 시중의 여러 서비스에서도 확인할 수 있습니다.\n매월 식단은 월 초에 공식적인 가정통신문으로 학생들에게 안내합나다. 다만, 급식 식단은 식자재 수급현황, 학교일정 등으로 사전공지 없이 변경될 수 있으므로 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
    "학교 급식을 알려줘", "학교 급식 메뉴는 월 초에 공식적인 가정통신문으로 학생들에게 안내합니다.\n가정통신문이 없다면 학교 홈페이지 혹은 학생회 공식 인스타그램 스토리에서 확인할 수 있으며, 나이스(교육청)의 점심메뉴 api를 활용하는 시중의 여러 서비스에서도 확인할 수 있습니다.\n급식 식단은 식자재 수급현황, 학교 일정 등으로 사전 공지 없이 변경될 수 있으므로 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",

    "학교 공식 홈페이지 링크를 알려줘", "선린인터넷고등학교의 공식 홈페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",
    "학교 홈페이지를 알려줘", "선린인터넷고등학교의 홈페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",
    "학교 웹사이트를 알려줘", "선린인터넷고등학교의 웹페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",

    "학생회에 대해서 설명해줘", "현재 선린인터넷고등학교의 학생회는 1개로, 118대 학생회 백업이 운영하고 있습니다.",
    "학생회 정보를 알고싶어", "현재 선린인터넷고등학교의 학생회는 1개로, 118대 학생회 백업이 운영되고 있습니다.",
    "학생회는 어떻게 운영되나요?", "현재 선린인터넷고등학교의 학생회는 1개로, 118대 학생회 백업이 운영되고 있습니다.",
    "학생회에 들어가고 싶어요", "학생회는 매년 초에 1학년을 대상으로 공식적인 기수를 모집합니다.\n학생회에 들어가기 위해서는 자기소개서 제출 후 면접의 과정을 거쳐야하며, 매 기수마다 1n명 정도의 학생회원을 모집하고 있습니다.\n긴혹 학기중에 .5기수를 모집하는 경우도 있습니다. 따라서 학생회에 들어가고 싶은 학생은 학생회 인스타그램이나 학교 내 공지를 주기적으로 확인하는 것이 좋겠습니다.",
    "학생회 모집 정보", "학생회는 매년 초에 1학년을 대상으로 공식적인 기수를 모집합니다.\n학생회에 들어가기 위해서는 자기소개서 제출 후 면접의 과정을 거쳐야하며, 매 기수마다 1n명 정도의 학생회원을 모집하고 있습니다.\n긴혹 학기중에 .5기수를 모집하는 경우도 있습니다. 따라서 학생회에 들어가고 싶은 학생은 학생회 인스타그램이나 학교 내 공지를 주기적으로 확인하는 것이 좋겠습니다.",
    "학생회 모집 기간", "학생회는 매년 초에 1학년을 대상으로 공식적인 기수를 모집합니다.\n학생회에 들어가기 위해서는 자기소개서 제출 후 면접의 과정을 거쳐야하며, 매 기수마다 1n명 정도의 학생회원을 모집하고 있습니다.\n긴혹 학기중에 .5기수를 모집하는 경우도 있습니다. 따라서 학생회에 들어가고 싶은 학생은 학생회 인스타그램이나 학교 내 공지를 주기적으로 확인하는 것이 좋겠습니다.",
    "학생회 공식 인스타그램", "118대 학생회 백업의 공식 인스타그램 계정은 sunrin_official 이며, 매일 학생회 인스타그램 스토리에는 당일의 점심 메뉴가 올라옵니다.\n 이외에도 학교 이벤트와 공지, 공식일정도 학생회 인스타그램을 통해 공지됩니다.\n학교의 다양한 행사와 일정을 알고 싶다면 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
    "학생회 공지 확인하는 방법", "학생회의 공식 인스타그램을 주기적으로 확인하세요. 학생회 인스타그램에는 당일의 점심 메뉴, 학교 이벤트와 공지, 학생회원 모집공고 등 다양한 정보가 학생회 인스타그램을 통해 공지됩니다.\n학교의 다양한 행사와 일정을 알고 싶다면 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",

    "학교의 과 구성을 알고싶어", "선린인터넷고등학교는 3개 학년별 12개 반으로,\n1~3반: 정보보호과, 4~6반: 소프트웨어과, 7~9반: IT경영과, 10~12반: 콘텐츠디자인과로 구성되어 있습니다.",
    "선린인터넷고등학교의 과 구성을 알려줘", "선린인터넷고등학교는 3개 학년별 12개 반으로,\n1~3반: 정보보호과, 4~6반: 소프트웨어과, 7~9반: IT경영과, 10~12반: 콘텐츠디자인과로 구성되어 있습니다.",

    "학교의 동아리 구성을 알고싶어", "선린인터넷고등학교의 동아리는 전공동아리, 일반동아리, 자율동아리로 구성됩니다.\n전공동아리와 일반동아리는 둘 중 하나만 들어갈 수 있으며, 자율동아리는 개수 구분없이 자유롭게 들어갈 수 있습니다.",
    "선린인터넷고등학교의 동아리 구성을 알려줘", "선린인터넷고등학교의 동아리는 전공동아리, 일반동아리, 자율동아리로 구성됩니다.\n전공동아리와 일반동아리는 둘 중 하나만 들어갈 수 있으며, 자율동아리는 개수 구분없이 자유롭게 들어갈 수 있습니다.",
    "전공동아리에 들어가고 싶어", "전공동아리는 1학년 초기에 부원을 모집합니다.\n전공동아리에 들어가기 위해서는 포트폴리오 제출 후 면접의 과정을 거쳐야하며, 매 기수마다 1n명 정도의 동아리 부원을 모집합니다.\n간혹 학기중에 .5기수를 모집하는 경우도 있습니다.",
    "전공동아리에 들어가는 방법", "전공동아리는 1학년 초기에 부원을 모집합니다.\n전공동아리에 들어가기 위해서는 포트폴리오 제출 후 면접의 과정을 거쳐야하며, 매 기수마다 1n명 정도의 동아리 부원을 모집합니다.\n간혹 학기중에 .5기수를 모집하는 경우도 있습니다.",

    "학교 와이파이를 알려줘", "선린인터넷고등학교의 공개 와이파이는 sen_WiFiFree 입니다. 비밀번호는 수시로 변경될 가능성이 있으므로 주변 선생님들께 확인하는 것이 좋겠습니다.",
    "와이파이 비밀번호를 알려줘", "선린인터넷고등학교의 공개 와이파이는 sen_WiFiFree 입니다. 비밀번호는 수시로 변경될 가능성이 있으므로 주변 선생님들께 확인하는 것이 좋겠습니다.",
    "와이파이를 알고싶어", "선린인터넷고등학교의 공개 와이파이는 sen_WiFiFree 입니다. 비밀번호는 수시로 변경될 가능성이 있으므로 주변 선생님들께 확인하는 것이 좋겠습니다.",

    "선린인터넷고등학교의 창립 연도를 알려줘", "선린인터넷고등학교의 창립 연도는 1899년입니다.",
    "학교의 설립일이 언제야?", "선린인터넷고등학교의 설립일은 1899년 6월 24일입니다.",
    "선린인터넷고등학교 교장 선생님 성함을 알려줘", "선린인터넷고등학교의 교장 선생님 성함은 박종은입니다.",
    "교장 선생님 성함을 알려줘", "선린인터넷고등학교의 교장 선생님 성함은 박종은입니다.",
    "선린인터넷고등학교의 전화번호를 알려줘", "선린인터넷고등학교의 전화번호는 +82 2-731-6221 입니다.",
    "학교 전화번호를 알려줘", "선린인터넷고등학교의 전화번호는 +82 2-731-6221 입니다.",
    "교내 대회를 알고싶어", "선린인터넷고등학교의 교내 대회는 천하제일 코딩대회, 해커톤, 디지털콘텐츠경진대회, 소프트웨어 나눔축제 등이 있습니다.",
    "학교에서 진행하는 대회의 종류를 알려줘", "선린인터넷고등학교의 교내 대회는 천하제일 코딩대회, 해커톤, 디지털콘텐츠경진대회, 소프트웨어 나눔축제 등이 있습니다."


]

# %%
data['train']['instruction'] = []
data['train']['output'] = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c4251bdcf852> in <cell line: 1>()
# ----> 1 data['train']['instruction'] = []
#       2 data['train']['output'] = []
#
# TypeError: 'Dataset' object does not support item assignment

# %%
# new_dataset = {}
# new_dataset['instruction'] = []
# new_dataset['output'] = []

data['train']['instruction'] = []
data['train']['output'] = []

for i in range(len(dataset_test)):
  if (i % 2) == 0:
    # new_dataset['instruction'].append(dataset_test[i])
    data['train']['instruction'].append(dataset_test[i])
  elif (i % 2) != 0:
    # new_dataset['output'].append(dataset_test[i])
    data['train']['output'].append(dataset_test[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-83e18b66c19e> in <cell line: 5>()
#       3 # new_dataset['output'] = []
#       4
# ----> 5 data['train']['instruction'] = []
#       6 data['train']['output'] = []
#       7
#
# TypeError: 'Dataset' object does not support item assignment

# %%
dataset['instruction'] = []

# %%
print(len(new_dataset['instruction']))
print(len(new_dataset['output']))
# Out:
# 128
# 128

# %%
print(new_dataset)
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?', '선린인터넷고등학교의 위치를 알려줘', '학교의 동네를 알려줘', '선린인터넷고등학교의 자세한 위치를 알려줘', '선린인터넷고등학교의 자세한 위치를 알고싶어', '남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?', '선린인터넷고등학교 주변에는 뭐가있어?', '선린인터넷고등학교 주변에 숙명여자대학교가 있어?', '선린인터넷고등학교 후문은 어떻게 갈 수 있어?', '선린인터넷고등학교 후문에서 정문까지는 거리가 멀어?', '선린인터넷고등학교는 남영역과 효창공원역 중에서 어떤 역과 더 가까워?', '효창공원역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?', '효창공원역에서 선린인터넷고등학교 까지 버스를 이용하고 싶어', '선린인터넷고등학교는 선린중학교랑 같이 있어?', '선린인터넷고등학교 후문은 어디에 있어?', '후문은 어디에 있어?', '후문은 어떻게 갈 수 있어?', '정문에서 후문으로 가는 길을 알려줘', '1호관에서 후문으로 가는 길을 알려줘', '2호관에서 후문으로 가는 길을 알려줘', '3호관에서 후문으로 가는 길을 알려줘', '4호관에서 후문으로 가는 길을 알려줘', '4호관은 어디에 있어?', '4호관은 어떻게 갈 수 있어?', '4호관으로 가는 길을 알려줘', '정문에서 4호관으로 가는 길을 알려줘', '1호관에서 4호관으로 가는 길을 알려줘', '2호관에서 4호관으로 가는 길을 알려줘', '3호관에서 4호관으로 가는 길을 알려줘', '후문에서 4호관으로 가는 길을 알려줘', '3호관은 어디에 있어?', '3호관은 어떻게 갈 수 있어?', '3호관으로 가는 길을 알려줘', '정문에서 3호관으로 가는 길을 알려줘', '1호관에서 3호관으로 가는 길을 알려줘', '2호관에서 3호관으로 가는 길을 알려줘', '4호관에서 3호관으로 가는 길을 알려줘', '후문에서 3호관으로 가는 길을 알려줘', '2호관은 어디에 있어?', '2호관은 어떻게 갈 수 있어?', '2호관
# ...

# %%
for i in range(len(new_dataset['instruction'])):
  print(new_dataset['instruction'][i], new_dataset['output'][i], end='\n\n', sep='->')
# Out:
# 선린인터넷고등학교는 어느 동네에 위치해있어?->선린인터넷고등학교는 용산구 남영동에 위치해있습니다.
#
# 선린인터넷고등학교의 위치를 알려줘->선린인터넷고등학교는 용산구 원효로 97길에 위치해있습니다.
#
# 학교의 동네를 알려줘->선린인터넷고등학교는 서울시 용산구 남영동에 위치해있습니다.
#
# 선린인터넷고등학교의 자세한 위치를 알려줘->선린인터넷고등학교는 서울특별시 용산구 원효로 97길 33-4에 위치해있습니다.
#
# 선린인터넷고등학교의 자세한 위치를 알고싶어->선린인터넷고등학교의 자세한 주소는 서울특별시 용산구 원효로 97길 33-4 입니다.
#
# 남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?->남영역에서 선린인터넷고등학교 까지 도보로 약 7분 입니다.
# 남영역 출구 바로 건너편에 선린인터넷고등학교가 자리하고있으며, 횡단보도를 2번 건너면 선린인터넷고등학교 정문이 나옵니다.
#
# 선린인터넷고등학교 주변에는 뭐가있어?->선린인터넷고등학교 주변에는 숙명여자대학교, 선린중학교, 남영역 등이 있습니다.
#
# 선린인터넷고등학교 주변에 숙명여자대학교가 있어?->네, 선린인터넷고등학교 주변에는 숙명여자대학교가 있습니다.
# 정획하게는, 선린 중학교 후문 건너편 지하주차장을 건너면 숙명여자대학교 캠퍼스가 나옵니다. 도보로 약 7분 정도가 소요됩니다.
#
# 선린인터넷고등학교 후문은 어떻게 갈 수 있어?->선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다.
# 후문은 4호관과 맞닿아있는 선린중학교 운동장을 돌아서 접근할 수 있으며, 4호관에서 후문까지 약 5분가량 소요됩니다.
#
# 선린인터넷고등학교 후문에서 정문까지는 거리가 멀어?->선린인터넷고등학교 정문과 후문 사이를 이동하는데 소요되는 시간은 약 10분이며, 4호관에서 후문까지는 약 5분가량 소요됩니다.
# 선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다.
#
# ...

# %%
print(len(new_dataset['instruction']))
print(len(new_dataset['output']))
# Out:
# 128
# 128

# %%
#@title 저장할 데이터셋 이름(경로) 지정 + 확장자
datasetName = 'TestDataset_6' #@param {type: "string"}

# %%
# !pip install pandas

import pandas as pd

dataframe = pd.DataFrame(new_dataset)


dataframe.to_parquet("/content/drive/MyDrive/Colab Notebooks/LLM 파인튜닝 프로젝트 (Gemma-2B) 학교 안내 챗봇/SchoolHelperChatbot-Gemma2B-Finetuning/Dataset/parquet/" + datasetName + '.parquet')

# %% [markdown]
# # 데이터셋 테스트 (로드)

# %%
#@title 🤗 Choose Dataset
dataset = 'taeseo06/SchoolHelperChatbot-dataset' #@param {type: "string"}

# %%
###########################################
# 5-1. 데이터셋 다운로드
# dataset 링크를 바꾸면 됨.
load_data = load_dataset(dataset)
# print(data_['train']) # 개수: 19079/
# Out:
# ...
# Generating train split:   0%|          | 0/128 [00:00<?, ? examples/s]

# %%
print(load_data['train'])
# Out:
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 128
# })

# %%
load_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 128
#     })
# })

# %%
load_data['train']
# Out:
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 999
# })

# %%
load_data['train'][0]
# Out:
# {'instruction': '선린인터넷고등학교는 어느 동네에 위치해있어?',
#  'output': '선린인터넷고등학교는 용산구 남영동에 위치해있습니다.'}
