# %% [markdown]
# # 데이터셋 수정 및 업로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# #@title 🤗 Choose Dataset
# dataset = 'kyujinpy/Open-platypus-Commercial' #@param {type: "string"}

# %%
# #@title 🤗 Choose Dataset
# dataset = 'beomi/KoAlpaca-v1.1a' #@param {type: "string"}

# %%
dataset = 'taeseo06/Taeseo06-personalization-dataset' #@param {type: "string"}

# %%
###########################################
# 5-1. 데이터셋 다운로드
# dataset 링크를 바꾸면 됨.
data = load_dataset(dataset)
print(data['train']) # 개수
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 720
# })

# %%
print(data) # 데이터셋 구조 파악
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 720
#     })
# })

# %%
# # import pickle

# # with open("/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_1.pickle", "wb")  as  fw:
# #       pickle.dump(data, fw)


# data.save_to_disk('/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_1')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/19079 [00:00<?, ? examples/s]

# %%
# import pickle

# with open("/content/drive/MyDrive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset_2/dataset.pickle", "wb")  as  fw:
#       pickle.dump(data, fw)

# %%
# with open("/content/drive/My Drive/Colab Notebooks/방학 세특 - LLM 파인튜닝 프로젝트 (model-llama2)/Dataset/dataset.pickle", "wb") as fw:
#     pickle.dump(data, fw)

# %%
# data = load_dataset(dataset)
new_dataset = data['train'][:2] # 새로운 데이터셋 생성 - 2개 인풋만 남김
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?', '선린인터넷고등학교의 위치를 알려줘'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.', '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다']}

# %%
del new_dataset['url'] # 기존 데이터셋에서 필요없는 요소가 있으면 제거

# %%
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?', '선린인터넷고등학교의 위치를 알려줘'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.', '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다']}

# %% [markdown]
# ---
# # 테스트

# %%
new_dataset = {}

# %%
print(len(new_dataset['instruction']))
print(len(new_dataset['output']))
# Out:
# 44
# 44

# %%
# new_dataset['input'] = list()

# 4/7 -  메인 데이터셋을 구성합니다. 'instruction', 'output'은 필수로 사용하고 'input'은 추후 추가합니다.
''' 데이터셋 구성 내용->
  위치 (구, 동, 시, 정밀한 위치)
  거리 (남영역, 효창공원역, 삼각지역, 숙대입구 역, 공덕역, 자차)
  정보/사이트 (공식 홈페이지, 동아리 페이지, 인스타그램)
  시설 (실습실, 교실, 급식실, 교장실, 학생회실, 동아리실, 체육관, 영상교육관, 운동장, 산책로, 방송실, 교무실)
  과 별로 설명? (교과목, 반 구분, 야구부)
'''

new_dataset['instruction'] = ["선린인터넷고등학교는 어느 동네에 위치해있어?",
                              "선린인터넷고등학교의 위치를 알려줘",
                              "학교의 동네를 알려줘",
                              "선린인터넷고등학교의 자세한 위치를 알려줘",
                              "선린인터넷고등학교의 자세한 위치를 알고싶어"
                              "남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?",
                              "선린인터넷고등학교 주변에는 뭐가있어?",
                              "선린인터넷고등학교 주변에 숙명여자대학교가 위치해있어?",
                              "선린인터넷고등학교 후문은 어떻게 갈 수 있어?",
                              "선린인터넷고등학교 후문에서 정문까지는 거리가 멀어?"
                              "선린인터넷고등학교는 남영역과 효창공원역 중에서 어떤 역과 더 가까워?"
                              "효창공원역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?",
                              "효창공원역에서 선린인터넷고등학교 까지 버스를 이용하고 싶어",
                              "선린인터넷고등학교는 선린중학교랑 같이 있어?",
                              "선린인터넷고등학교 후문은 어디에 있어?",
                              "후문은 어떻게 갈 수 있어?",
                              "매점은 어디에 있어?",
                              "매점은 어떻게 갈 수 있어?",
                              "4호관은 어떻게 갈 수 있어?",
                              "4호관으로 가는 길을 알려줘",
                              "4호관에서 3호관으로 갈 수 있는 방법을 알려줘",
                              "선린인터넷고등학교의 세게로 미래로 산책로는 어디에있어?",
                              "급식실은 어디에 있어?",
                              "급식실은 어떻게 갈 수 있어?",
                              "급식실로 가는 길을 알려줘",
                              "급식 시간을 알려줘",
                              "학년별 급식실 이용 시간을 알려줘",
                              "학교 급식 메뉴는 어디서 확인할 수 있어?",
                              "학교 공식 홈페이지 링크를 알려줘",
                              "학교 홈페이지를 알려줘",
                              "학교 웹사이트를 알려줘",
                              "현재 선린인터넷고등학교의 학생회 정보를 알려줘",
                              "학생회실 위치를 알려줘",
                              "학생회의 인스타그램을 알려줘",
                              "선린인터넷고등학교 학생회에 공식적으로 문의를 할 수 있는 방법을 알려줘",
                              "선린인터넷고드학교의 과 구성을 알려줘",
                              "학교의 과 구성을 알고싶어",
                              "과 구성을 알고싶어",
                              "선린인터넷고등학교 동아리의 구성을 알고싶어",
                              "동아리의 구성을 알고싶어",
                              "전공동아리에 들어가려면 어떻게 준비해야돼?",
                              "학교 학생회에 들어가고싶어",
                              "학교 학생회에 들어가려면 어떻게 준비해야돼?",
                              "오늘 학교 급식을 알려줘",
                              "체육관의 위치를 알려줘",
                              "체육관에 어떻게 갈 수 있어?",
                              "학교의 와이파이 비밀번호를 알려줘"

                              ]

new_dataset['output'] = ["선린인터넷고등학교는 용산구 남영동에 위치해있습니다.",
                         "선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다.",
                         "선린인터넷고등학교는 서울시 용산구에 위치해있습니다.",
                         "선린인터넷고등학교는 서울특별시 용산구 원효로 97길 33-4에 위치해있습니다.",
                         "선린인터넷고등학교의 주소는 서울특별시 용산구 원효로 97길 33-4 입니다.",
                         "남영역에서 선린인터넷고등학교 까지 도보로 약 7분 입니다. 남영역 출구 바로 건너편에 선린인터넷고등학교가 자리하고있으며, 도보로 횡단보도를 2번 건너서 5분 정도 걸어가면 선린인터넷고등학교가 나옵니다.",
                         "선린인터넷고등학교 주변에는 숙명여자 대학교, 선린중학교, 남영역 등이 위치해 있습니다.",
                         "네, 선린인터넷고등학교 주변에는 숙명여자대학교가 있습니다. 정획하게는, 선린 중학교 후문 건너편 지하주차장을 건너면 숙명여자대학교 캠퍼스가 나옵니다. 약 7분 정도가 소요됩니다.",
                         "선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다. 후문은 4호관과 맞닿아있는 선린중학교 운동장을 돌아서 접근할 수 있으며, 약 5분가량 소요됩니다.",
                         "선린인터넷고등학교 정문과 후문 사이를 이동하는데 소요되는 시간은 약 10분 입니다. 선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용하고 있습니다."
                         "선린인터넷고등학교는 남영역과 더 가깝습니다. 남영역에서 선린인터넷고등학교 까지는 약 7분, 효창공원역에서 선린인터넷고등학교 까지는 약 15분이 걸립니다. 그러나 효창공원역 앞에서 버스를 이용하면 소요되는 시간은 더 줄어들 수도 있습니다.",
                         "효창공원역에서 선린인터넷고등학교 까지 도보로 약 15분 입니다. 효창공원역 출구로 나와서 금양초등학교 방면으로 걷다보면 선린중학교가 먼저 나오고, 선린중학교를 거쳐서 선린인터넷고등학교로 접근할 수 있습니다. 그러나 효창공원역 출구에서 0411 혹은 400번 버스를 이용하면 소요되는 시간은 더 줄어들 수도 있습니다.",
                         "효창공원역 출구에서 0411 혹은 400번 버스를 이용하여 숙명여대 정류장에 내려서 숙명여대 지하주차장을 통과하면 선린중학교가 나옵니다. 선린중학교를 거쳐서 선린인터넷고등학교로 접근할 수 있습니다.",
                         "네, 선린인터넷고등학교는 선린중학교와 이어져 있으며, 등교과 하교 시간에 고등학교 학생들이 선린중학교로 등학교 하거나, 선린중학교 학생들이 선린인터넷고등학교 정문으로 등학교 하기도 합니다.",
                         "선린인터넷고등학교 후문은 선린중학교 정문과 함께 사용됩니다. 선린인터넷고등학교 학생들이 등하교 시간에 선린중학교를 이용할 수 있습니다. 또한, 선린인터넷고등학교 정문도 선린중학교 학생들이 등하교 시간에 이용할 수 있습니다.",
                         "후문은 선린중학교 정문과 함께 사용하고 있으며, 4호관과 맞닿아있는 선린중학교 운동장을 돌아서 접근할 수 있습니다.",
                         "매점은 4호관과 3호관 사이에 위치해 있으며, 영상교육관 건물 외부에 위치해 있습니다.",
                         "매점은 4호관과 3호관 사이에 위치해 있으며, 영상교육관 건물 외부에 위치해 있습니다.",
                         "4호관은 2호관 맞은편에 위치해 있으며, 영상교육관 쪽 외부 문으로 들어가거나, 3호관 2층에서 4호관과 연결되어있는 통로를 통해서 접근할 수 있습니다."
                         "4호관은 2호관 맞은편에 위치해 있으며, 영상교육관 쪽 외부 문으로 들어가거나, 3호관 2층에서 4호관과 연결되어있는 통로를 통해서 갈 수 있습니다.",
                         "4호관과 3호관은 각 2층 연결통로로 이어져있습니다. 따라서 4호관 2층으로 이동한 다음, 연결되어있는 통로를 통해서 3호관으로 갈 수 있습니다.",
                         "선린인터넷고등학교 세게로 미래로 산책길은 학교 정문에서 선린중학교로 향하는 길로 올라가면 볼 수 있습니다. 산책로는 선린인터넷고등학교의 운동장을 둘러쌓는 형태로 조성되어 있으며, 끝까지 올라가면 선린중학교 운동장으로 갈 수 있습니다.",
                         "급식실은 3호관 1층 중앙에 위치해 있습니다."
                         "급식실은 3호관 1층 중앙에 위치해 있으며, 4, 2호관을 통해 3호관으로 간 다음 급식실로 내려가거나, 매점 건너편에 있는 급식실 1층 출입문을 통해 갈 수 있습니다.",
                         "급식실은 3호관 1층 중앙 출입구로 갈 수 있으며, 4, 2호관을 통해 3호관으로 간 다음 급식실로 내려가거나, 2호관 급식실 방향 출입구를 통해서 바로 갈 수도 있습니다.",
                         "선린인터넷고등학교 급식시간은 12시30분 부터 1시30분까지 1시간이며, 3학년 2학년 1학년 순서대로 입장하여 점심을 먹을 수 있습니다.",
                         "전체적인 학생 급식 시간은 12시30분 부터 1시30분까지 1시간이며, 학년별로 급식실 이용 시간이 명확하게 분류되어있지는 않습니다. 그러나 급식시간이 되면 관행대로 3학년 2학년 1학년 순서대로 급식실에 입장합니다.",
                         "매일 점심 메뉴는 학교 홈페이지 혹은 학생회 공식 인스타그램 스토리에서 매일 확인할 수 있으며, 나이스(교육청)의 점심메뉴 api를 활용하는 시중의 여러 서비스에서도 확인할 수 있습니다. 매월 식단은 월 초에 공식적인 가정통신문으로 학생들에게 안내합나다. 급식 식단은 식자재 수급현황, 학교 일정 등으로 사전 공지 없이 변경될 수 있으므로 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
                         "선린인터넷고등학교의 공식적인 홈페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",
                         "선린인터넷고등학교의 홈페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",
                         "선린인터넷고등학교의 웹페이지 링크는 https://sunrint.sen.hs.kr/ 입니다.",
                         "현재 선린인터넷고등학교의 학생회는 1개로, 118대 학생회 백업이 운영되고 있습니다.",
                         "학생회실은 1호관 2층 왼쪽 끝에 위치해 있으며, 현재 선린인터넷고등학교의 공식적인 학생회는 118대 학생회 백업입니다.",
                         "118대 학생회 백업의 공식 인스타그램 계정은 sunrin_official 이며, 매일 학생회 인스타그램 스토리에는 당일의 점심 메뉴가 올라옵니다. 이외에도 학교 이벤트와 공지, 공식일정도 학생회 인스타그램을 통해 공지됩니다. 학교의 다양한 행사와 일정을 알고 싶다면 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
                         "선린인터넷고등학교 공식 학생회인 118대 백업의 학생회실은 1호관 2층 외쪽 끝에 있습니다. 학생은 언제든지 학생회실에 방문해서 건의 또는 문의 할 수 있으며, 이 외에도 학생회 백업은 공싱 인스타그램을 운영중입니다. 118대 학생회 백업의 공식 인스타그램 계정은 sunrin_official 입니다. 매일 학생회 인스타그램 스토리에는 당일의 점심 메뉴가 올라옵니다. 이외에도 학교 이벤트와 공지, 공식일정도 학생회 인스타그램을 통해 공지됩니다. 학교의 다양한 행사와 일정을 알고 싶다면 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다",
                         "선린인터넷고등학교는 한 학년당 12개의 반을 운영하고 있습니다. 선린인터넷고등학교에는 정보보호과, 소프트웨어과, IT경영과, 콘텐츠디자인과 총 4개의 과가 있으며, 각 과당 3개의 반을 개설하고 있습니다. 자세히는 1~3반:정보보호과, 4~6반:소프트웨어과, 7~9반:IT경영과, 10~12반:콘텐츠디자인과 입니다.",
                         "선린인터넷고등학교는 한 학년당 12개의 반을 운영하고 있습니다. 선린인터넷고등학교에는 정보보호과, 소프트웨어과, IT경영과, 콘텐츠디자인과 총 4개의 과가 있으며, 각 과당 3개의 반을 개설하고 있습니다. 자세히는 1~3반:정보보호과, 4~6반:소프트웨어과, 7~9반:IT경영과, 10~12반:콘텐츠디자인과 입니다.",
                         "학교는 한 학년당 12개의 반을 운영하고 있습니다. 선린인터넷고등학교에는 정보보호과, 소프트웨어과, IT경영과, 콘텐츠디자인과 총 4개의 과가 있으며, 각 과당 3개의 반을 개설하고 있습니다. 자세히는 1~3반:정보보호과, 4~6반:소프트웨어과, 7~9반:IT경영과, 10~12반:콘텐츠디자인과 입니다.",
                         "선린인터넷고등학교는 동아리를 일반동아리, 전공동아리, 자율동아리로 나누어서 운영중이며, 전공동아리 혹은 일반동아리는 학생당 하나씩 입부하여 활동할 수 있습니다. 자율동아리는 입부에 제한이있지 않습니다. 전공동아리는 1학년 초기에 입부 안내가 이루어지며, 각자 포트폴리오와 면접을 준비하여 지원할 수 있습니다.",
                         "학교는 동아리를 일반동아리, 전공동아리, 자율동아리로 나누어서 운영중이며, 전공동아리 혹은 일반동아리는 학생당 하나씩 입부하여 활동할 수 있습니다. 자율동아리는 입부에 제한이있지 않습니다. 전공동아리는 1학년 초기에 입부 안내가 이루어지며, 각자 포트폴리오와 면접을 준비하여 지원할 수 있습니다.",
                         "전공동아리는 1학년 초기에 입부 안내가 이루어지며, 각자 포트폴리오와 면접을 준비하여 지원할 수 있습니다.",
                         "학교의 공식적인 학생회는 118대 백업입니다. 이 학생회에 들어가려면 학생회에서 안내하는 다음기수 학생회 모집 공고에 지원해야합니다. 간혹 .5기수를 지원받기도 하며, 주된 대상은 1학년, 2학년입니다.",
                         "선린인터넷고등학교 118대 학생회 백업에 들어가기 위해서는 학생회에서 안내하는 다음기수 학생회 모집 공고에 지원해야합니다. 학생회 지원양식은 학생회에서 안내하는 양식대로 작성해서 제출해야하며, 작성한 자기소개서를 바탕으로 면접이 진행됩니다.",
                         "선린인터넷고등학교 급식 식단은 월 초에 공식적인 가정통신문으로 학생들에게 안내합니다. 가정통신문이 없다면 학교 홈페이지 혹은 학생회 공식 인스타그램 스토리에서 확인할 수 있으며, 나이스(교육청)의 점심메뉴 api를 활용하는 시중의 여러 서비스에서도 확인할 수 있습니다. 급식 식단은 식자재 수급현황, 학교 일정 등으로 사전 공지 없이 변경될 수 있으므로 학교 홈페이지 혹은 학생회 인스타그램을 주기적으로 확인하는 것이 좋겠습니다.",
                         "체육관은 정문과 운동장, 산책로 사이에 위치해있으며, 건물 2층에 체육관이 있습니다. 건물의 1층은 음악실, 인공지능실, 선린 장학재단 사무실, 야구부실이 있습니다.",
                         "체육관은 정문과 운동장, 산책로 사이에 위치해있습니다. 1호관에서 체육관에 가려면 1호관 1층의 현관으로 나와서 정문방향으로 길을 따라서 가다보면 체육관 건물이 나옵니다.",
                         "선린인터넷고등학교의 공개 와이파이는 sen_WiFi 입니다. 비밀번호는 수시로 변경될 가능성이 있으므로 주변에 선생님들께 확인하는 것이 좋겠습니다."

                         ]

# %%
# 3/20 추가: 같은 문장을 여러번 사용하도록 하는 데이터셋 수정 - input은 사용하지 않겠습니다.

new_dataset['instruction'] = []
new_dataset['output'] = []

for i in range(1, 1000):
  new_dataset['instruction'].append("문태서의 생일은 언제야?")
  new_dataset['output'].append("문태서의 생일은 9월 17일 입니다.")

# %%
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?',
#   '선린인터넷고등학교의 위치를 알려줘',
#   '선린인터넷고등학교의 동네를 알려줘',
#   '선린인터넷고등학교의 자세한 위치를 알려줘',
#   '남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?',
#   '선린인터넷고등학교 주변에는 뭐가있어?'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.',
#   '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다',
#   '선린인터넷고등학교는 서울시 용산구에 위치해있습니다',
#   '선린인터넷고등학교는 서울특별시 용산구 원효로 97길 33-4에 위치해있습니다',
#   '남영역에서 선린인터넷고등학교 까지의 거리는 약 5분 입니다. 남영역 출구 바로 건너편에 선린인터넷고등학교가 자리하고있으며, 도보로 횡단보도를 2번 건너서 5분 정도 걸어가면 선린인터넷고등학교가 나옵니다.',
#   '선린인터넷고등학교 주변에는 숙명여자 대학교, 선린중학교 등이 위치해 있습니다.']}

# %%
# for i in range(len(new_dataset['instruction'])): # 설정한 데이터셋의 행의 맞게 input (고정 프롬프트)의 개수를 조정해서 저장
#   new_dataset['input'].append("너는 문태서에 관한 데이터로 파인튜닝 된 문태서GPT야. 넌 사용자가 질문하는 문태서의 관련한 정보에 관해 학습한 데이터를 기반으로 정확한 정보를 전달해야 해.")

# %%
new_dataset
# Out:
# {'instruction': ['선린인터넷고등학교는 어느 동네에 위치해있어?',
#   '선린인터넷고등학교의 위치를 알려줘',
#   '선린인터넷고등학교의 동네를 알려줘',
#   '선린인터넷고등학교의 자세한 위치를 알려줘',
#   '남영역에서 선린인터넷고등학교 까지 거리가 어떻게 돼?',
#   '선린인터넷고등학교 주변에는 뭐가있어?'],
#  'output': ['선린인터넷고등학교는 용산구 남영동에 위치해있습니다.',
#   '선린인터넷고등학교는 용산구 원횰97길에 위치해있습니다',
#   '선린인터넷고등학교는 서울시 용산구에 위치해있습니다',
#   '선린인터넷고등학교는 서울특별시 용산구 원효로 97길 33-4에 위치해있습니다',
#   '남영역에서 선린인터넷고등학교 까지의 거리는 약 5분 입니다. 남영역 출구 바로 건너편에 선린인터넷고등학교가 자리하고있으며, 도보로 횡단보도를 2번 건너서 5분 정도 걸어가면 선린인터넷고등학교가 나옵니다.',
#   '선린인터넷고등학교 주변에는 숙명여자 대학교, 선린중학교 등이 위치해 있습니다.']}

# %%
#@title 저장할 데이터셋 이름(경로) 지정 + 확장자
datasetName = 'TestDataset_5' #@param {type: "string"}

# %%
# !pip install pandas

import pandas as pd

dataframe = pd.DataFrame(new_dataset)


dataframe.to_parquet("/content/drive/MyDrive/Colab Notebooks/LLM 파인튜닝 프로젝트 (Gemma-2B) 학교 안내 챗봇/SchoolHelperChatbot-Gemma2B-Finetuning/Dataset/parquet/" + datasetName + '.parquet')

# %% [markdown]
# # 데이터셋 테스트 (로드)

# %%
#@title 🤗 Choose Dataset
dataset = 'taeseo06/Taeseo06-personalization-dataset' #@param {type: "string"}

# %%
###########################################
# 5-1. 데이터셋 다운로드
# dataset 링크를 바꾸면 됨.
load_data = load_dataset(dataset)
# print(data_['train']) # 개수: 19079/
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
print(load_data['train'])
# Out:
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 6
# })

# %%
load_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'output'],
#         num_rows: 6
#     })
# })

# %%
load_data['train']
# Out:
# Dataset({
#     features: ['instruction', 'output'],
#     num_rows: 999
# })

# %%
load_data['train'][0]
# Out:
# {'instruction': '선린인터넷고등학교는 어느 동네에 위치해있어?',
#  'output': '선린인터넷고등학교는 용산구 남영동에 위치해있습니다.'}
